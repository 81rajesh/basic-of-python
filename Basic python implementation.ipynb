# %% [markdown]
# # Variable
# Variable is the value which we want to store in memory. Example, In our we save a contact by person's name so that person's name is variable. Variable always get stored in memory(RAM) not in hard disk. If you restart the kernel and try to find the value of a it will give you a error. Type() is predefined function.

# %%
a=10

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
type(a)
# Out:
# int

# %%
b=41.2
type(b)
# Out:
# float

# %%
c='rajesh'
type(c)
print(c)
# Out:
# rajesh

# %%
bool(c)
# Out:
# True

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Comment

# %%
# a is variable holding 10 (single line comment)
a=10
a
# Out:
# 10

# %%
#multiline comment
'''this is my first coding
a is variable holding 10'''
# Out:
# 'this is my first coding\na is variable holding 10'

# %%
k='my number is 10+z'
k
# Out:
# 'my number is 10+z'

# %%
x=5-6j

# %%
x
type(x)
# Out:
# complex

# %%
x.real
# Out:
# 5.0

# %%
x.imag
# Out:
# -6.0

# %%
a='rajesh'

# %%
a.capitalize()
a.isascii()
# Out:
# True

# %%
b=10
b.numerator
# Out:
# 10

# %%
c=False
c
# Out:
# False

# %%
True + (True)
# Out:
# 2

# %%
'rajesh'+" patil"
# Out:
# 'rajesh patil'

# %%
'rajesh' * 2
# Out:
# 'rajeshrajesh'

# %% [markdown]
# Input function
# Input function always read your data or obsn as string

# %%
z=input()
# Out:
# patil

# %%
z
# Out:
# 'patil'

# %%
type(z)
# Out:
# str

# %%
type(40)
# Out:
# int

# %% [markdown]
# Type casting

# %%
m=int(input())
# Out:
# 45

# %%
type(m)
# Out:
# int
