# %%
t=(1,2,3,'rajesh')

# %%
type(t)
# Out:
# tuple

# %%
l=[32,55,6,4,"patil"]

# %%
type(l)
# Out:
# list

# %%
t[0]
# Out:
# 1

# %%
t[-1]
# Out:
# 'rajesh'

# %%
t[0:4]
# Out:
# (1, 2, 3, 'rajesh')

# %%
l[0:4]
# Out:
# [32, 55, 6, 4]

# %%
l[1]=21

# %%
l
# Out:
# [32, 21, 6, 4, 'patil']

# %%
t[0]=26
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-01defdf66f81> in <module>
# ----> 1 t[0]=26
#
# TypeError: 'tuple' object does not support item assignment

# %%
l=[(1,23,3,4),(7,7,8,8)]

# %%
l
# Out:
# [(1, 23, 3, 4), (7, 7, 8, 8)]

# %%
s={}

# %%
type(s)
# Out:
# dict

# %%
s={2,3,4,(1,2),4+7j}

# %%
type(s)
# Out:
# set

# %% [markdown]
# SET
# Set is the data structure in which it stores all kind of values. But it removes duplicate values.

# %%
s={1,1,1,2,5,6,6,7,8}

# %%
s
# Out:
# {1, 2, 5, 6, 7, 8}

# %%
s1={'Rajesh','rajesh'}

# %%
s1
# Out:
# {'Rajesh', 'rajesh'}

# %%
s={9,8,7,6,5}

# %%
s
# Out:
# {5, 6, 7, 8, 9}

# %%
s={164,54,87,8,989,6763,611}

# %%
s
# Out:
# {8, 54, 87, 164, 611, 989, 6763}

# %%
s={'a','c','gdg',163026,6564,5493,6893}

# %%
s
# Out:
# {163026, 5493, 6564, 6893, 'a', 'c', 'gdg'}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-c9c96910e542> in <module>
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
l=list(s)

# %%
l
# Out:
# ['a', 6564, 'gdg', 6893, 163026, 'c', 5493]

# %%
l[0:5]
# Out:
# ['a', 6564, 'gdg', 6893, 163026]

# %%
s1=set(l)

# %%
s1
# Out:
# {163026, 5493, 6564, 6893, 'a', 'c', 'gdg'}

# %%
t
# Out:
# (1, 2, 3, 'rajesh')

# %%
l=list(t)

# %%
l
# Out:
# [1, 2, 3, 'rajesh']

# %%
l[0]=100

# %%
tuple(l)
# Out:
# (100, 2, 3, 'rajesh')

# %% [markdown]
# Dictionary
# Dict is  a key-value function. It stores the values with some keys. The values and keys are always separated by ':'. In Dict 'key' should be  a unique value. Key can take any kind of data type except special characters(#, $). Yes it can within string('#rajesh'). Key cant take any data structure of collection like list,set,dict,etc. But values can all these collections.

# %%
d={}

# %%
d={'name':'rajesh', 'mname':'ravindra','lname':'patil','number':165111,'mail':'avcv@.com'}

# %%
d
# Out:
# {'name': 'rajesh',
#  'mname': 'ravindra',
#  'lname': 'patil',
#  'number': 165111,
#  'mail': 'avcv@.com'}

# %%
d={'name':'rajesh','name':'patil'}

# %%
d
# Out:
# {'name': 'patil'}

# %%
d={123:'rajesh','name':'patil'}

# %%
d
# Out:
# {123: 'rajesh', 'name': 'patil'}

# %%
d={2.3:'rajesh','name':'patil'}

# %%
d
# Out:
# {2.3: 'rajesh', 'name': 'patil'}

# %%
d={4+7j:'rajesh','name':'patil'}

# %%
d
# Out:
# {(4+7j): 'rajesh', 'name': 'patil'}

# %%
d={_name:'rajesh','name':'patil'}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-06e8dd84d5d0> in <module>
# ----> 1 d={_name:'rajesh','name':'patil'}
#
# NameError: name '_name' is not defined

# %%
d={'_name':'rajesh','name':'patil'}

# %%
d
# Out:
# {'_name': 'rajesh', 'name': 'patil'}

# %%
d={'name':'rajesh','s':('s','d',1,2),'t':(1,2,3),'l':[1,2,30],'d1':{'x':23}}

# %%
d
# Out:
# {'name': 'rajesh',
#  's': ('s', 'd', 1, 2),
#  't': (1, 2, 3),
#  'l': [1, 2, 30],
#  'd1': {'x': 23}}

# %%
d={'[1,2,3]:'rajesh',(1,23,65):('s','d',1,2),'t':(1,2,3),'l':[1,2,30],'d1':{'x':23}}
# Out:
#   File "<ipython-input-96-9fd11bbef7a9>", line 1
#     d={'[1,2,3]:'rajesh',(1,23,65):('s','d',1,2),'t':(1,2,3),'l':[1,2,30],'d1':{'x':23}}
#                  ^
# SyntaxError: invalid syntax

# %%
d={'name':'rajesh','s':('s','d',1,2),'t':(1,2,3),'l':[1,2,30],'d1':{'x':23}}

# %%
d['name']
# Out:
# 'rajesh'

# %%
d={[1,2,3]:'abc'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-8f8a8cd33081> in <module>
# ----> 1 d={[1,2,3]:'abc'}
#
# TypeError: unhashable type: 'list'

# %%
d={{1,2,30}:'abc'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-5dbc233765a7> in <module>
# ----> 1 d={{1,2,30}:'abc'}
#
# TypeError: unhashable type: 'set'

# %%
d={{'name':'abx'}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-61850c5d22eb> in <module>
# ----> 1 d={{'name':'abx'}}
#
# TypeError: unhashable type: 'dict'

# %%
s=('name','abc',65,2.3)

# %%
type(s)
# Out:
# tuple

# %%
s='gshhj bbjjd'

# %%
type(s)
# Out:
# str

# %%
s[0]='c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-6591b8d03f29> in <module>
# ----> 1 s[0]='c'
#
# TypeError: 'str' object does not support item assignment

# %%
d={'name':'rajesh','s':('s','d',1,2),'t':(1,2,3),'l':[1,2,30],'d1':{'x':23},'set':{1,3,25,4}}

# %%
d['s'][1]
# Out:
# 'd'

# %%
d['set'][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-1df97b4dfc43> in <module>
# ----> 1 d['set'][0]
#
# TypeError: 'set' object is not subscriptable

# %%
l=list(d['set'])

# %%
l
# Out:
# [1, 3, 4, 25]

# %%
l[2]
# Out:
# 4

# %%
d['d1']['x']
# Out:
# 23

# %%
d['lname']='patil'

# %%
d
# Out:
# {'name': 'rajesh',
#  's': ('s', 'd', 1, 2),
#  't': (1, 2, 3),
#  'l': [1, 2, 30],
#  'd1': {'x': 23},
#  'set': {1, 3, 4, 25},
#  'lname': 'patil'}

# %%
d['name']='ravindra'

# %%
d
# Out:
# {'name': 'ravindra',
#  's': ('s', 'd', 1, 2),
#  't': (1, 2, 3),
#  'l': [1, 2, 30],
#  'd1': {'x': 23},
#  'set': {1, 3, 4, 25},
#  'lname': 'patil'}

# %%
d[(1,2)]='new'

# %%
d
# Out:
# {'name': 'ravindra',
#  's': ('s', 'd', 1, 2),
#  't': (1, 2, 3),
#  'l': [1, 2, 30],
#  'd1': {'x': 23},
#  'set': {1, 3, 4, 25},
#  'lname': 'patil',
#  (1, 2): 'new'}

# %%
d.keys()
# Out:
# dict_keys(['name', 's', 't', 'l', 'd1', 'set', 'lname', (1, 2)])

# %%
l=[1,3,555,565,7,98,65,14,'rajesh',[1,2,3],{2,6,655,5,5,6},(45,40,45),(30,35,98),{'name':'rajesh'},10.5]

# %%
for i in l:
    print(i)
# Out:
# 1
# 3
# 555
# 565
# 7
# 98
# 65
# 14
# rajesh
# [1, 2, 3]
# {2, 5, 6, 655}
# (45, 40, 45)
# (30, 35, 98)
# {'name': 'rajesh'}
# 10.5

# %%
for i in l:
    if i>10:
        print(i)
# Out:
# 555
# 565
# 98
# 65
# 14

# %%
for i in l:
    if type(i)==str:
        print(i)
# Out:
# rajesh

# %%
for i in l:
    if type(i)==float:
        print(i)
# Out:
# 10.5

# %%
for i in l:
    if type(i)==list:
        for j in i:
            if j == 2:
                print(j)
# Out:
# 2

# %%
l
# Out:
# [1,
#  3,
#  555,
#  565,
#  7,
#  98,
#  65,
#  14,
#  'rajesh',
#  [1, 2, 3],
#  {2, 5, 6, 655},
#  (45, 45, 45),
#  {'name': 'rajesh'},
#  10.5]

# %%
for i in l:
    if type(i)==tuple:
        print(i)
        for j in i:
            if j==35:
                print(j)
            
# why output showing 3 lines?
# Out:
# (45, 40, 45)
# (30, 35, 98)
# 35

# %%
for i in l:
    if type(i) ==tuple:
        for j in i:
            if j ==45:
                print('yes i get 45')
            else:
                print('no i dont get 45')
# Out:
# yes i get 45
# no i dont get 45
# yes i get 45
# no i dont get 45
# no i dont get 45
# no i dont get 45

# %%
d={'name':'rajesh','mail':'abc.com','no':[1,2,161,65,200,2]}

# %%
for i in d:
    print(i)
# Out:
# name
# mail
# no

# %%
d.values()
# Out:
# dict_values(['rajesh', 'abc.com', 123])

# %%
for i in d.values() :
    print(i)
# Out:
# rajesh
# abc.com
# 123

# %%
for i in d.keys():
    print(d[i])
# Out:
# rajesh
# abc.com
# 123

# %%
for i in d.keys():
    if type(d[i]) ==int:
        print(d[i])

# %%
for i in d.items():
    if type(i[1])==list:
        print(i[1])
        
        for j in i[1]:
            if j>10:
                print('element',j)
            else :
                print('xhx')
#doubt
# Out:
# [1, 2, 161, 65, 200, 2]
# xhx
# xhx
# element 161
# element 65
# element 200
# xhx

# %%
for i in d.items():
    print(i)
# Out:
# ('name', 'rajesh')
# ('mail', 'abc.com')
# ('no', [1, 2, 161, 65, 200, 2])

# %%
s='rajesh'

# %%
s[::-1]
# Out:
# 'hsejar'
